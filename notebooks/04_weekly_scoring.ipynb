# %% [markdown]
# # 04 Batch Inference
#
# Load the promoted production model and score new customer/account records.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

from src.score_accounts import run_score_accounts

predictions = run_score_accounts(
    input_path=PROJECT_ROOT / "data" / "inference" / "weekly_scoring_batch.csv",
    output_path=PROJECT_ROOT / "outputs" / "predictions" / "customer_risk_predictions.csv",
    model_path=PROJECT_ROOT / "outputs" / "model_registry" / "production" / "customer_risk_pipeline.joblib",
)
predictions.head()

# %%
predictions["risk_category"].value_counts(normalize=True)

# %%
predictions.sort_values("risk_probability", ascending=False).head(20)[["customer_id", "risk_probability", "risk_category", "recommended_action"]]
